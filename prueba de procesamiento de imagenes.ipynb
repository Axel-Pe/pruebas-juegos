# %%
import tensorflow as tf

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
import cv2 as cv

from IPython import display

# %%
size=(20,20)
imagen_aleatoria = np.random.rand(size[0],size[1])
plt.imshow(imagen_aleatoria,vmin=0,vmax=1)

# %%
 cv.imread('C:/Users/axel/Desktop/ia/img_pixel.jpg')
# Out:
# array([[[158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158],
#         ...,
#         [158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158]],
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158],
#         ...,
#         [158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158]],
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158],
#         ...,
#         [158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158]],
#
#        ...,
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158],
#         ...,
#         [158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158]],
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158],
#         ...,
#         [158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158]],
#
#        [[158, 158, 158],
#         [158, 158, 158],
#         [158, 158, 158],
# ...

# %%
img = cv.imread('C:/Users/axel/Desktop/ia/img_pixel.jpg')
cv.namedWindow("hola")
cv.imshow('hola',img)
cv.waitKey(0)
# Out:
# -1

# %%
img = cv.imread('C:/Users/axel/Desktop/ia/img_pixel.jpg')
#plt.imshow(img, cmap = 'gray', interpolation = 'none')
plt.imshow(img)
plt.xticks([]), plt.yticks([]) 
plt.show()

# %%
img =cv.imread('C:/Users/axel/Desktop/ia/img_pixel.jpg')

plt.imsave("pixel.txt",img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-716ddd3f199e> in <module>
#       1 img =cv.imread('C:/Users/axel/Desktop/ia/img_pixel.jpg')
#       2
# ----> 3 plt.imsave("pixel.txt",img)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imsave(fname, arr, **kwargs)
#    2155 @docstring.copy_dedent(matplotlib.image.imsave)
#    2156 def imsave(fname, arr, **kwargs):
# -> 2157     return matplotlib.image.imsave(fname, arr, **kwargs)
#    2158
#    2159
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi)
#    1432         fig.figimage(arr, cmap=cmap, vmin=vmin, vmax=vmax, origin=origin,
#    1433                      resize=True)
# -> 1434         fig.savefig(fname, dpi=dpi, format=format, transparent=True)
#    1435
#    1436
#
# ...

# %%
import csv
img =cv.imread('C:/Users/axel/Desktop/ia/img_pixel.jpg')
#np.savetxt('tabla.dat', img)
with open('img.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(img)
